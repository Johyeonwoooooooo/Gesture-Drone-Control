# %%
import open3d as o3d
import numpy as np

# .ply 파일 로드
pcd = o3d.io.read_point_cloud("/Users/gyucheol/Workspace/Projects/Prometheus/DroneGesture/src/playground/data/Scan at 20.59.ply")

# 데이터 구조 확인 (포인트 개수 등)
print(pcd)
#print(np.asarray(pcd.points))

# 시각화 (마우스로 돌려보며 구조 확인)
#o3d.visualization.draw_geometries([pcd])
# Out:
# PointCloud with 1191904 points.
